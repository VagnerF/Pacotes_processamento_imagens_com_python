# %%
from Img_Processing_py.utils import io, plot
from Img_Processing_py.processing import combination, transformation

# %%
image1 = io.read_image("recife.jpg")
image2 = io.read_image("sol.jpg")

# %%
plot.plot_image(image1)
plot.plot_image(image2)

# %%
resultado = combination.transfer_histogram(image1, image2)
plot.plot_image(resultado)
# Out:
# C:\Users\Win10\anaconda3\lib\site-packages\Img_Processing_py\processing\combination.py:16: FutureWarning: `multichannel` is a deprecated argument name for `match_histograms`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   match_image =  match_histograms(image1, image2, multichannel=True)
